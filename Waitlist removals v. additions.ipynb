# %%
#import pandas
import pandas as pd

# %%
#import waitlist additions
df_addition = pd.read_csv('addition.csv')

# %%
#drop nan values
df_addition.dropna()
# Out:
#         year   2022   2021   2020   2019   2018   2017   2016   2015   2014  \
# 0  additions  62586  60538  55118  61223  58702  54884  54295  53048  54238
#
#    ...   2004   2003   2002   2001   2000   1999   1998   1997   1996   1995
# 0  ...  43046  39924  38586  39319  39282  38106  35368  32773  31399  30471
#
# [1 rows x 29 columns]

# %%
#import waitlist removals
df_removal = pd.read_csv('removal.csv')

# %%
#check removals
df_removal
# Out:
#           year   2022   2021   2020   2019   2018   2017   2016   2015   2014  \
# 0  All Removal  60762  59178  56801  58583  56578  55133  54157  52032  48982
# 1   Transplant  41307  39843  37572  38424  35269  33504  32354  29792  28250
# 2         Died   5529   6326   6202   5273   5649   5875   6209   6693   6732
#
#    ...   2004   2003   2002   2001   2000   1999   1998   1997   1996   1995
# 0  ...  37270  35412  35928  33225  31863  30335  27816  25881  24838  24018
# 1  ...  24009  22323  21837  21075  20244  19194  18734  17708  17187  16983
# 2  ...   6903   6726   6788   6710   6126   6514   5173   4487   4000   3498
#
# [3 rows x 29 columns]

# %%
#merge data
data = [df_addition, df_removal]
merged = pd.concat(data)

# %%
#display merged data
merged
# Out:
#           year   2022   2021   2020   2019   2018   2017   2016   2015   2014  \
# 0    additions  62586  60538  55118  61223  58702  54884  54295  53048  54238
# 0  All Removal  60762  59178  56801  58583  56578  55133  54157  52032  48982
# 1   Transplant  41307  39843  37572  38424  35269  33504  32354  29792  28250
# 2         Died   5529   6326   6202   5273   5649   5875   6209   6693   6732
#
#    ...   2004   2003   2002   2001   2000   1999   1998   1997   1996   1995
# 0  ...  43046  39924  38586  39319  39282  38106  35368  32773  31399  30471
# 0  ...  37270  35412  35928  33225  31863  30335  27816  25881  24838  24018
# 1  ...  24009  22323  21837  21075  20244  19194  18734  17708  17187  16983
# 2  ...   6903   6726   6788   6710   6126   6514   5173   4487   4000   3498
#
# [4 rows x 29 columns]

# %%
#export as CSV
merged.to_csv("output.csv", index=False)
